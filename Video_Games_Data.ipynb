# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading csv file

# %%
dirty_df = pd.read_csv("Video_Games.csv")

# %% [markdown]
# # Investigating the dirty dataframe

# %%
dirty_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
dirty_df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# # Finding NaN values

# %%
dirty_df.isnull()
# Out:
#         Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False     False            False  False      False     False     False
# 1      False     False            False  False      False     False     False
# 2      False     False            False  False      False     False     False
# 3      False     False            False  False      False     False     False
# 4      False     False            False  False      False     False     False
# ...      ...       ...              ...    ...        ...       ...       ...
# 16714  False     False            False  False      False     False     False
# 16715  False     False            False  False      False     False     False
# 16716  False     False            False  False      False     False     False
# 16717  False     False            False  False      False     False     False
# 16718  False     False            False  False      False     False     False
#
# ...

# %%
dirty_df.isnull().any()
# Out:
# Name                True
# Platform           False
# Year_of_Release     True
# Genre               True
# Publisher           True
# NA_Sales           False
# EU_Sales           False
# JP_Sales           False
# Other_Sales        False
# Global_Sales       False
# Critic_Score        True
# Critic_Count        True
# User_Score          True
# User_Count          True
# Developer           True
# Rating              True
# dtype: bool

# %%
dirty_df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# # Creating clean dataframe

# %%
drop_columns = ["Critic_Score","Critic_Count","User_Score","User_Count","Developer","Publisher","Name"]

# %%
naDropped_df = dirty_df.dropna()

# %%
naDropped_df.tail(5)
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
#                           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16667                      NewKidCo      0.01      0.00       0.0
# 16677                  Midway Games      0.01      0.00       0.0
# 16696  Konami Digital Entertainment      0.00      0.01       0.0
# 16700                     Destineer      0.01      0.00       0.0
# 16706                       Unknown      0.00      0.01       0.0
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# ...

# %%
clean_df = naDropped_df.drop(drop_columns,axis=1)

# %%
clean_df.head(5)
# Out:
#   Platform  Year_of_Release     Genre  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports     41.36     28.96      3.77
# 2      Wii           2008.0    Racing     15.68     12.76      3.79
# 3      Wii           2009.0    Sports     15.61     10.93      3.28
# 6       DS           2006.0  Platform     11.28      9.14      6.50
# 7      Wii           2006.0      Misc     13.96      9.18      2.93
#
#    Other_Sales  Global_Sales Rating
# 0         8.45         82.53      E
# 2         3.29         35.52      E
# 3         2.95         32.77      E
# 6         2.88         29.80      E
# 7         2.84         28.92      E

# %% [markdown]
# # Investigating the clean dataframe

# %%
clean_df.head(5)
# Out:
#   Platform  Year_of_Release     Genre  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports     41.36     28.96      3.77
# 2      Wii           2008.0    Racing     15.68     12.76      3.79
# 3      Wii           2009.0    Sports     15.61     10.93      3.28
# 6       DS           2006.0  Platform     11.28      9.14      6.50
# 7      Wii           2006.0      Misc     13.96      9.18      2.93
#
#    Other_Sales  Global_Sales Rating
# 0         8.45         82.53      E
# 2         3.29         35.52      E
# 3         2.95         32.77      E
# 6         2.88         29.80      E
# 7         2.84         28.92      E

# %%
clean_df.columns
# Out:
# Index(['Platform', 'Year_of_Release', 'Genre', 'NA_Sales', 'EU_Sales',
#        'JP_Sales', 'Other_Sales', 'Global_Sales', 'Rating'],
#       dtype='object')

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Platform         6825 non-null   object
#  1   Year_of_Release  6825 non-null   float64
#  2   Genre            6825 non-null   object
#  3   NA_Sales         6825 non-null   float64
#  4   EU_Sales         6825 non-null   float64
#  5   JP_Sales         6825 non-null   float64
#  6   Other_Sales      6825 non-null   float64
#  7   Global_Sales     6825 non-null   float64
#  8   Rating           6825 non-null   object
# dtypes: float64(6), object(3)
# memory usage: 533.2+ KB

# %%
for column in clean_df.columns:
  print(f"{column}\n : {clean_df[f'{column}'].unique()}")
# Out:
# Platform
#  : ['Wii' 'DS' 'X360' 'PS3' 'PS2' '3DS' 'PS4' 'PS' 'XB' 'PC' 'PSP' 'WiiU'
#  'GC' 'GBA' 'XOne' 'PSV' 'DC']
# Year_of_Release
#  : [2006. 2008. 2009. 2005. 2007. 2010. 2013. 2004. 2002. 2001. 2011. 2012.
#  2014. 1997. 1999. 2015. 2016. 2003. 1998. 1996. 2000. 1994. 1985. 1992.
#  1988.]
# Genre
#  : ['Sports' 'Racing' 'Platform' 'Misc' 'Action' 'Puzzle' 'Shooter'
#  'Fighting' 'Simulation' 'Role-Playing' 'Adventure' 'Strategy']
# NA_Sales
#  : [4.136e+01 1.568e+01 1.561e+01 1.128e+01 1.396e+01 1.444e+01 9.710e+00
#  8.920e+00 1.500e+01 9.010e+00 7.020e+00 9.430e+00 4.740e+00 9.660e+00
#  8.410e+00 3.430e+00 6.850e+00 9.040e+00 9.700e+00 4.990e+00 8.250e+00
#  8.520e+00 5.540e+00 6.990e+00 6.620e+00 5.030e+00 5.990e+00 3.960e+00
#  2.500e+00 7.970e+00 3.010e+00 6.060e+00 6.760e+00 4.020e+00 4.890e+00
#  2.960e+00 4.760e+00 6.730e+00 5.950e+00 3.660e+00 7.040e+00 6.650e+00
#  3.880e+00 5.800e+00 4.100e+00 5.930e+00 2.030e+00 4.400e+00 5.050e+00
# ...

# %%
clean_df.nunique()
# Out:
# Platform            17
# Year_of_Release     25
# Genre               12
# NA_Sales           351
# EU_Sales           273
# JP_Sales           157
# Other_Sales        144
# Global_Sales       536
# Rating               7
# dtype: int64

# %%
columns = ["Genre","Year_of_Release","Rating","Platform"]

# %%
for column in clean_df[columns]:
  print(f"{column}:\n{clean_df[f'{column}'].unique()} ")
# Out:
# Genre:
# ['Sports' 'Racing' 'Platform' 'Misc' 'Action' 'Puzzle' 'Shooter'
#  'Fighting' 'Simulation' 'Role-Playing' 'Adventure' 'Strategy']
# Year_of_Release:
# [2006. 2008. 2009. 2005. 2007. 2010. 2013. 2004. 2002. 2001. 2011. 2012.
#  2014. 1997. 1999. 2015. 2016. 2003. 1998. 1996. 2000. 1994. 1985. 1992.
#  1988.]
# Rating:
# ['E' 'M' 'T' 'E10+' 'AO' 'K-A' 'RP']
# Platform:
# ['Wii' 'DS' 'X360' 'PS3' 'PS2' '3DS' 'PS4' 'PS' 'XB' 'PC' 'PSP' 'WiiU'
#  'GC' 'GBA' 'XOne' 'PSV' 'DC']

# %% [markdown]
# # Visualizing Dataset

# %% [markdown]
# ## Getting Dataframe values

# %%
game_genre = clean_df["Genre"]
game_yor = clean_df["Year_of_Release"]
game_rating = clean_df["Rating"]
game_platform = clean_df["Platform"]
game_EU = clean_df["EU_Sales"]
game_NA = clean_df["NA_Sales"]
game_JP = clean_df["JP_Sales"]
game_OT = clean_df["Other_Sales"]
game_GL = clean_df["Global_Sales"]
game_region_sales = clean_df[["EU_Sales","NA_Sales","JP_Sales"]]

# %%
sports_sales = clean_df[clean_df["Genre"] == "Sports"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
sports_EU = sports_sales.loc["EU_Sales"]
sports_NA = sports_sales.loc["NA_Sales"]
sports_JP = sports_sales.loc["JP_Sales"]
sports_GL = sports_sales.loc["Global_Sales"]
sports_Other = sports_sales.loc["Other_Sales"]
sports_sales
# Out:
# EU_Sales        247.43
# NA_Sales        457.52
# JP_Sales         34.54
# Global_Sales    833.85
# Other_Sales      94.05
# dtype: float64

# %%
shooter_sales = clean_df[clean_df["Genre"] == "Shooter"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
shooter_EU = shooter_sales.loc["EU_Sales"]
shooter_NA = shooter_sales.loc["NA_Sales"]
shooter_JP = shooter_sales.loc["JP_Sales"]
shooter_GL = shooter_sales.loc["Global_Sales"]
shooter_Other = shooter_sales.loc["Other_Sales"]
shooter_sales
# Out:
# EU_Sales        261.12
# NA_Sales        448.76
# JP_Sales         18.57
# Global_Sales    816.48
# Other_Sales      87.90
# dtype: float64

# %%
action_sales = clean_df[clean_df["Genre"] == "Action"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
action_EU = action_sales.loc["EU_Sales"]
action_NA = action_sales.loc["NA_Sales"]
action_JP = action_sales.loc["JP_Sales"]
action_GL = action_sales.loc["Global_Sales"]
action_Other = action_sales.loc["Other_Sales"]
action_sales
# Out:
# EU_Sales         387.78
# NA_Sales         591.23
# JP_Sales          76.17
# Global_Sales    1203.16
# Other_Sales      147.46
# dtype: float64

# %%
racing_sales = clean_df[clean_df["Genre"] == "Racing"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
racing_EU = racing_sales.loc["EU_Sales"]
racing_NA = racing_sales.loc["NA_Sales"]
racing_JP = racing_sales.loc["JP_Sales"]
racing_GL = racing_sales.loc["Global_Sales"]
racing_Other = racing_sales.loc["Other_Sales"]
racing_sales
# Out:
# EU_Sales        164.66
# NA_Sales        225.59
# JP_Sales         27.76
# Global_Sales    476.22
# Other_Sales      58.29
# dtype: float64

# %%
platform_sales = clean_df[clean_df["Genre"] == "Platform"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
platform_EU = platform_sales.loc["EU_Sales"]
platform_NA = platform_sales.loc["NA_Sales"]
platform_JP = platform_sales.loc["JP_Sales"]
platform_GL = platform_sales.loc["Global_Sales"]
platform_Other = platform_sales.loc["Other_Sales"]
platform_sales
# Out:
# EU_Sales        108.56
# NA_Sales        193.60
# JP_Sales         43.09
# Global_Sales    377.80
# Other_Sales      32.53
# dtype: float64

# %%
misc_sales = clean_df[clean_df["Genre"] == "Misc"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
misc_EU = misc_sales.loc["EU_Sales"]
misc_NA = misc_sales.loc["NA_Sales"]
misc_JP = misc_sales.loc["JP_Sales"]
misc_GL = misc_sales.loc["Global_Sales"]
misc_Other = misc_sales.loc["Other_Sales"]
misc_sales
# Out:
# EU_Sales        120.46
# NA_Sales        222.05
# JP_Sales         33.22
# Global_Sales    416.26
# Other_Sales      40.41
# dtype: float64

# %%
puzzle_sales = clean_df[clean_df["Genre"] == "Puzzle"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
puzzle_EU = puzzle_sales.loc["EU_Sales"]
puzzle_NA = puzzle_sales.loc["NA_Sales"]
puzzle_JP = puzzle_sales.loc["JP_Sales"]
puzzle_GL = puzzle_sales.loc["Global_Sales"]
puzzle_Other = puzzle_sales.loc["Other_Sales"]
puzzle_sales
# Out:
# EU_Sales        24.04
# NA_Sales        33.50
# JP_Sales        14.98
# Global_Sales    78.90
# Other_Sales      6.33
# dtype: float64

# %%
fighting_sales = clean_df[clean_df["Genre"] == "Fighting"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
fighting_EU = fighting_sales.loc["EU_Sales"]
fighting_NA = fighting_sales.loc["NA_Sales"]
fighting_JP = fighting_sales.loc["JP_Sales"]
fighting_GL = fighting_sales.loc["Global_Sales"]
fighting_Other = fighting_sales.loc["Other_Sales"]
fighting_sales
# Out:
# EU_Sales         60.50
# NA_Sales        136.39
# JP_Sales         27.85
# Global_Sales    249.95
# Other_Sales      25.14
# dtype: float64

# %%
simulation_sales = clean_df[clean_df["Genre"] == "Simulation"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
simulation_EU = simulation_sales.loc["EU_Sales"]
simulation_NA = simulation_sales.loc["NA_Sales"]
simulation_JP = simulation_sales.loc["JP_Sales"]
simulation_GL = simulation_sales.loc["Global_Sales"]
simulation_Other = simulation_sales.loc["Other_Sales"]
simulation_sales
# Out:
# EU_Sales         67.29
# NA_Sales         92.12
# JP_Sales         26.16
# Global_Sales    202.70
# Other_Sales      17.14
# dtype: float64

# %%
rpg_sales = clean_df[clean_df["Genre"] == "Role-Playing"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
rpg_EU = rpg_sales.loc["EU_Sales"]
rpg_NA = rpg_sales.loc["NA_Sales"]
rpg_JP = rpg_sales.loc["JP_Sales"]
rpg_GL = rpg_sales.loc["Global_Sales"]
rpg_Other = rpg_sales.loc["Other_Sales"]
rpg_sales
# Out:
# EU_Sales        119.20
# NA_Sales        219.53
# JP_Sales        122.47
# Global_Sales    501.37
# Other_Sales      40.36
# dtype: float64

# %%
adventure_sales = clean_df[clean_df["Genre"] == "Adventure"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
adventure_EU = adventure_sales.loc["EU_Sales"]
adventure_NA = adventure_sales.loc["NA_Sales"]
adventure_JP = adventure_sales.loc["JP_Sales"]
adventure_GL = adventure_sales.loc["Global_Sales"]
adventure_Other = adventure_sales.loc["Other_Sales"]
adventure_sales
# Out:
# EU_Sales        25.06
# NA_Sales        38.81
# JP_Sales         8.73
# Global_Sales    80.75
# Other_Sales      8.05
# dtype: float64

# %%
strategy_sales = clean_df[clean_df["Genre"] == "Strategy"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
strategy_EU = strategy_sales.loc["EU_Sales"]
strategy_NA = strategy_sales.loc["NA_Sales"]
strategy_JP = strategy_sales.loc["JP_Sales"]
strategy_GL = strategy_sales.loc["Global_Sales"]
strategy_Other = strategy_sales.loc["Other_Sales"]
strategy_sales
# Out:
# EU_Sales        25.21
# NA_Sales        33.25
# JP_Sales         4.34
# Global_Sales    69.61
# Other_Sales      6.61
# dtype: float64

# %%
NA_df = pd.DataFrame(data = [sports_NA,racing_NA,platform_NA,misc_NA,action_NA,puzzle_NA,shooter_NA,fighting_NA,simulation_NA,rpg_NA,adventure_NA,strategy_NA],columns=["NA_Sales"])
NA_df["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
NA_df
# Out:
#     NA_Sales         Genre
# 0     457.52        Sports
# 1     225.59        Racing
# 2     193.60      Platform
# 3     222.05          Misc
# 4     591.23        Action
# 5      33.50        Puzzle
# 6     448.76       Shooter
# 7     136.39      Fighting
# 8      92.12    Simulation
# 9     219.53  Role-Playing
# 10     38.81     Adventure
# 11     33.25      Strategy

# %%
EU_df = pd.DataFrame(data = [sports_EU,racing_EU,platform_EU,misc_EU,action_EU,puzzle_EU,shooter_EU,fighting_EU,simulation_EU,rpg_EU,adventure_EU,strategy_EU],columns=["EU_Sales"])
EU_df["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
EU_df
# Out:
#     EU_Sales         Genre
# 0     247.43        Sports
# 1     164.66        Racing
# 2     108.56      Platform
# 3     120.46          Misc
# 4     387.78        Action
# 5      24.04        Puzzle
# 6     261.12       Shooter
# 7      60.50      Fighting
# 8      67.29    Simulation
# 9     119.20  Role-Playing
# 10     25.06     Adventure
# 11     25.21      Strategy

# %%
JP_df = pd.DataFrame(data = [sports_JP,racing_JP,platform_JP,misc_JP,action_JP,puzzle_JP,shooter_JP,fighting_JP,simulation_JP,rpg_JP,adventure_JP,strategy_JP],columns=["JP_Sales"])
JP_df["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
JP_df
# Out:
#     JP_Sales         Genre
# 0      34.54        Sports
# 1      27.76        Racing
# 2      43.09      Platform
# 3      33.22          Misc
# 4      76.17        Action
# 5      14.98        Puzzle
# 6      18.57       Shooter
# 7      27.85      Fighting
# 8      26.16    Simulation
# 9     122.47  Role-Playing
# 10      8.73     Adventure
# 11      4.34      Strategy

# %%
GL_df = pd.DataFrame(data = [sports_GL,racing_GL,platform_GL,misc_GL,action_GL,puzzle_GL,shooter_GL,fighting_GL,simulation_GL,rpg_GL,adventure_GL,strategy_GL],columns=["GL_Sales"])
GL_df["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
GL_df
# Out:
#     GL_Sales         Genre
# 0     833.85        Sports
# 1     476.22        Racing
# 2     377.80      Platform
# 3     416.26          Misc
# 4    1203.16        Action
# 5      78.90        Puzzle
# 6     816.48       Shooter
# 7     249.95      Fighting
# 8     202.70    Simulation
# 9     501.37  Role-Playing
# 10     80.75     Adventure
# 11     69.61      Strategy

# %% [markdown]
# Let's create new dataframes to investigate nowadays.

# %%
new_dates_df = clean_df[clean_df["Year_of_Release"]>2015]
new_dates_df.head()
# Out:
#     Platform  Year_of_Release    Genre  NA_Sales  EU_Sales  JP_Sales  \
# 94       PS4           2016.0   Sports      0.66      5.75      0.08
# 171      PS4           2016.0  Shooter      1.85      2.50      0.19
# 245      PS4           2016.0  Shooter      1.61      2.00      0.15
# 289      PS4           2016.0  Shooter      1.10      2.15      0.21
# 325      PS4           2016.0  Shooter      1.35      1.70      0.15
#
#      Other_Sales  Global_Sales Rating
# 94          1.11          7.59      E
# 171         0.85          5.38      T
# 245         0.71          4.46      M
# 289         0.61          4.08      M
# 325         0.60          3.80      M

# %%
game_genreN = new_dates_df["Genre"]
game_yorN = new_dates_df["Year_of_Release"]
game_ratingN = new_dates_df["Rating"]
game_platformN = new_dates_df["Platform"]
game_EUN = new_dates_df["EU_Sales"]
game_NAN = new_dates_df["NA_Sales"]
game_JPN = new_dates_df["JP_Sales"]
game_OTN = new_dates_df["Other_Sales"]
game_GLN = new_dates_df["Global_Sales"]

# %%
sports_salesN = new_dates_df[new_dates_df["Genre"] == "Sports"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
sports_EUN = sports_salesN.loc["EU_Sales"]
sports_NAN = sports_salesN.loc["NA_Sales"]
sports_JPN = sports_salesN.loc["JP_Sales"]
sports_GLN = sports_salesN.loc["Global_Sales"]
sports_OtherN = sports_salesN.loc["Other_Sales"]
sports_salesN
# Out:
# EU_Sales        10.69
# NA_Sales         6.87
# JP_Sales         0.25
# Global_Sales    20.56
# Other_Sales      2.75
# dtype: float64

# %%
shooter_salesN = new_dates_df[new_dates_df["Genre"] == "Shooter"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
shooter_EUN = shooter_salesN.loc["EU_Sales"]
shooter_NAN = shooter_salesN.loc["NA_Sales"]
shooter_JPN = shooter_salesN.loc["JP_Sales"]
shooter_GLN = shooter_salesN.loc["Global_Sales"]
shooter_OtherN = shooter_salesN.loc["Other_Sales"]
shooter_salesN
# Out:
# EU_Sales        14.59
# NA_Sales        14.96
# JP_Sales         1.04
# Global_Sales    35.23
# Other_Sales      4.63
# dtype: float64

# %%
action_salesN = new_dates_df[new_dates_df["Genre"] == "Action"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
action_EUN = action_salesN.loc["EU_Sales"]
action_NAN = action_salesN.loc["NA_Sales"]
action_JPN = action_salesN.loc["JP_Sales"]
action_GLN = action_salesN.loc["Global_Sales"]
action_OtherN = action_salesN.loc["Other_Sales"]
action_salesN
# Out:
# EU_Sales         8.74
# NA_Sales         7.12
# JP_Sales         1.00
# Global_Sales    19.34
# Other_Sales      2.39
# dtype: float64

# %%
racing_salesN = new_dates_df[new_dates_df["Genre"] == "Racing"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
racing_EUN = racing_salesN.loc["EU_Sales"]
racing_NAN = racing_salesN.loc["NA_Sales"]
racing_JPN = racing_salesN.loc["JP_Sales"]
racing_GLN = racing_salesN.loc["Global_Sales"]
racing_OtherN = racing_salesN.loc["Other_Sales"]
racing_salesN
# Out:
# EU_Sales        1.25
# NA_Sales        0.59
# JP_Sales        0.00
# Global_Sales    2.05
# Other_Sales     0.20
# dtype: float64

# %%
platform_salesN = new_dates_df[new_dates_df["Genre"] == "Platform"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
platform_EUN = platform_salesN.loc["EU_Sales"]
platform_NAN = platform_salesN.loc["NA_Sales"]
platform_JPN = platform_salesN.loc["JP_Sales"]
platform_GLN = platform_salesN.loc["Global_Sales"]
platform_OtherN = platform_salesN.loc["Other_Sales"]
platform_salesN
# Out:
# EU_Sales        0.40
# NA_Sales        0.59
# JP_Sales        0.07
# Global_Sales    1.20
# Other_Sales     0.14
# dtype: float64

# %%
misc_salesN = new_dates_df[new_dates_df["Genre"] == "Misc"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
misc_EUN = misc_salesN.loc["EU_Sales"]
misc_NAN = misc_salesN.loc["NA_Sales"]
misc_JPN = misc_salesN.loc["JP_Sales"]
misc_GLN = misc_salesN.loc["Global_Sales"]
misc_OtherN = misc_salesN.loc["Other_Sales"]
misc_salesN
# Out:
# EU_Sales        0.27
# NA_Sales        0.20
# JP_Sales        0.22
# Global_Sales    0.76
# Other_Sales     0.06
# dtype: float64

# %%
puzzle_salesN = new_dates_df[new_dates_df["Genre"] == "Puzzle"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
puzzle_EUN = puzzle_salesN.loc["EU_Sales"]
puzzle_NAN = puzzle_salesN.loc["NA_Sales"]
puzzle_JPN = puzzle_salesN.loc["JP_Sales"]
puzzle_GLN = puzzle_salesN.loc["Global_Sales"]
puzzle_OtherN = puzzle_salesN.loc["Other_Sales"]
puzzle_salesN
# Out:
# EU_Sales        0.0
# NA_Sales        0.0
# JP_Sales        0.0
# Global_Sales    0.0
# Other_Sales     0.0
# dtype: float64

# %%
fighting_salesN = new_dates_df[new_dates_df["Genre"] == "Fighting"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
fighting_EUN = fighting_salesN.loc["EU_Sales"]
fighting_NAN = fighting_salesN.loc["NA_Sales"]
fighting_JPN = fighting_salesN.loc["JP_Sales"]
fighting_GLN = fighting_salesN.loc["Global_Sales"]
fighting_OtherN = fighting_salesN.loc["Other_Sales"]
fighting_salesN
# Out:
# EU_Sales        1.30
# NA_Sales        1.77
# JP_Sales        0.57
# Global_Sales    4.15
# Other_Sales     0.51
# dtype: float64

# %%
simulation_salesN = new_dates_df[new_dates_df["Genre"] == "Simulation"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
simulation_EUN = simulation_salesN.loc["EU_Sales"]
simulation_NAN = simulation_salesN.loc["NA_Sales"]
simulation_JPN = simulation_salesN.loc["JP_Sales"]
simulation_GLN = simulation_salesN.loc["Global_Sales"]
simulation_OtherN = simulation_salesN.loc["Other_Sales"]
simulation_salesN
# Out:
# EU_Sales        1.09
# NA_Sales        0.10
# JP_Sales        0.00
# Global_Sales    1.28
# Other_Sales     0.12
# dtype: float64

# %%
rpg_salesN = new_dates_df[new_dates_df["Genre"] == "Role-Playing"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
rpg_EUN = rpg_salesN.loc["EU_Sales"]
rpg_NAN = rpg_salesN.loc["NA_Sales"]
rpg_JPN = rpg_salesN.loc["JP_Sales"]
rpg_GLN = rpg_salesN.loc["Global_Sales"]
rpg_OtherN = rpg_salesN.loc["Other_Sales"]
rpg_salesN
# Out:
# EU_Sales        1.62
# NA_Sales        1.51
# JP_Sales        1.10
# Global_Sales    4.72
# Other_Sales     0.52
# dtype: float64

# %%
adventure_salesN = new_dates_df[new_dates_df["Genre"] == "Adventure"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
adventure_EUN = adventure_salesN.loc["EU_Sales"]
adventure_NAN = adventure_salesN.loc["NA_Sales"]
adventure_JPN = adventure_salesN.loc["JP_Sales"]
adventure_GLN = adventure_salesN.loc["Global_Sales"]
adventure_OtherN = adventure_salesN.loc["Other_Sales"]
adventure_salesN
# Out:
# EU_Sales        0.61
# NA_Sales        0.57
# JP_Sales        0.09
# Global_Sales    1.47
# Other_Sales     0.20
# dtype: float64

# %%
strategy_salesN = new_dates_df[new_dates_df["Genre"] == "Strategy"][["EU_Sales","NA_Sales","JP_Sales","Global_Sales","Other_Sales"]].sum()
strategy_EUN = strategy_salesN.loc["EU_Sales"]
strategy_NAN = strategy_salesN.loc["NA_Sales"]
strategy_JPN = strategy_salesN.loc["JP_Sales"]
strategy_GLN = strategy_salesN.loc["Global_Sales"]
strategy_OtherN = strategy_salesN.loc["Other_Sales"]
strategy_salesN
# Out:
# EU_Sales        0.47
# NA_Sales        0.24
# JP_Sales        0.00
# Global_Sales    0.80
# Other_Sales     0.07
# dtype: float64

# %%
NA_dfN = pd.DataFrame(data = [sports_NAN,racing_NAN,platform_NAN,misc_NAN,action_NAN,puzzle_NAN,shooter_NAN,fighting_NAN,simulation_NAN,rpg_NAN,adventure_NAN,strategy_NAN],columns=["NA_Sales"])
NA_dfN["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
NA_dfN
# Out:
#     NA_Sales         Genre
# 0       6.87        Sports
# 1       0.59        Racing
# 2       0.59      Platform
# 3       0.20          Misc
# 4       7.12        Action
# 5       0.00        Puzzle
# 6      14.96       Shooter
# 7       1.77      Fighting
# 8       0.10    Simulation
# 9       1.51  Role-Playing
# 10      0.57     Adventure
# 11      0.24      Strategy

# %%
EU_dfN = pd.DataFrame(data = [sports_EUN,racing_EUN,platform_EUN,misc_EUN,action_EUN,puzzle_EUN,shooter_EUN,fighting_EUN,simulation_EUN,rpg_EUN,adventure_EUN,strategy_EUN],columns=["EU_Sales"])
EU_dfN["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
EU_dfN
# Out:
#     EU_Sales         Genre
# 0      10.69        Sports
# 1       1.25        Racing
# 2       0.40      Platform
# 3       0.27          Misc
# 4       8.74        Action
# 5       0.00        Puzzle
# 6      14.59       Shooter
# 7       1.30      Fighting
# 8       1.09    Simulation
# 9       1.62  Role-Playing
# 10      0.61     Adventure
# 11      0.47      Strategy

# %%
JP_dfN = pd.DataFrame(data = [sports_JPN,racing_JPN,platform_JPN,misc_JPN,action_JPN,puzzle_JPN,shooter_JPN,fighting_JPN,simulation_JPN,rpg_JPN,adventure_JPN,strategy_JPN],columns=["JP_Sales"])
JP_dfN["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
JP_dfN
# Out:
#     JP_Sales         Genre
# 0       0.25        Sports
# 1       0.00        Racing
# 2       0.07      Platform
# 3       0.22          Misc
# 4       1.00        Action
# 5       0.00        Puzzle
# 6       1.04       Shooter
# 7       0.57      Fighting
# 8       0.00    Simulation
# 9       1.10  Role-Playing
# 10      0.09     Adventure
# 11      0.00      Strategy

# %%
GL_dfN = pd.DataFrame(data = [sports_GLN,racing_GLN,platform_GLN,misc_GLN,action_GLN,puzzle_GLN,shooter_GLN,fighting_GLN,simulation_GLN,rpg_GLN,adventure_GLN,strategy_GLN],columns=["Global_Sales"])
GL_dfN["Genre"] = ["Sports","Racing","Platform","Misc","Action","Puzzle","Shooter","Fighting","Simulation","Role-Playing","Adventure","Strategy"]
GL_dfN
# Out:
#     Global_Sales         Genre
# 0          20.56        Sports
# 1           2.05        Racing
# 2           1.20      Platform
# 3           0.76          Misc
# 4          19.34        Action
# 5           0.00        Puzzle
# 6          35.23       Shooter
# 7           4.15      Fighting
# 8           1.28    Simulation
# 9           4.72  Role-Playing
# 10          1.47     Adventure
# 11          0.80      Strategy

# %%
Wii = clean_df[clean_df["Platform"]=="Wii"]["Platform"].count()
DS = clean_df[clean_df["Platform"]=="DS"]["Platform"].count()
X360 = clean_df[clean_df["Platform"]=="X360"]["Platform"].count()
PS3 = clean_df[clean_df["Platform"]=="PS3"]["Platform"].count()
PS2 = clean_df[clean_df["Platform"]=="PS2"]["Platform"].count()
threeDS = clean_df[clean_df["Platform"]=="3DS"]["Platform"].count()
PS4 = clean_df[clean_df["Platform"]=="PS4"]["Platform"].count()
PS = clean_df[clean_df["Platform"]=="PS"]["Platform"].count()
XB = clean_df[clean_df["Platform"]=="XB"]["Platform"].count()
PC = clean_df[clean_df["Platform"]=="PC"]["Platform"].count()
PSP = clean_df[clean_df["Platform"]=="PSP"]["Platform"].count()
WiiU = clean_df[clean_df["Platform"]=="WiiU"]["Platform"].count()
GC = clean_df[clean_df["Platform"]=="GC"]["Platform"].count()
GBA = clean_df[clean_df["Platform"]=="GBA"]["Platform"].count()
XOne = clean_df[clean_df["Platform"]=="XOne"]["Platform"].count()
PSV = clean_df[clean_df["Platform"]=="PSV"]["Platform"].count()
DC = clean_df[clean_df["Platform"]=="DC"]["Platform"].count()

platform_df = pd.DataFrame(data=[Wii,DS,X360,PS3,PS2,threeDS,PS4,PS,XB,PC,PSP,WiiU,GC,GBA,XOne,PSV,DC],columns=["Platform_Counts"])
platform_df["Platform"] = ['Wii', 'DS', 'X360', 'PS3', 'PS2', '3DS', 'PS4', 'PS', 'XB', 'PC','PSP', 'WiiU', 'GC', 'GBA', 'XOne', 'PSV', 'DC']
platform_df
# Out:
#     Platform_Counts Platform
# 0               479      Wii
# 1               464       DS
# 2               858     X360
# 3               769      PS3
# 4              1140      PS2
# 5               155      3DS
# 6               239      PS4
# 7               150       PS
# 8               565       XB
# 9               651       PC
# 10              390      PSP
# 11               89     WiiU
# 12              348       GC
# 13              237      GBA
# 14              159     XOne
# 15              118      PSV
# 16               14       DC

# %%
WiiN = new_dates_df[new_dates_df["Platform"]=="Wii"]["Platform"].count()
DSN = new_dates_df[new_dates_df["Platform"]=="DS"]["Platform"].count()
X360N = new_dates_df[new_dates_df["Platform"]=="X360"]["Platform"].count()
PS3N = new_dates_df[new_dates_df["Platform"]=="PS3"]["Platform"].count()
PS2N = new_dates_df[new_dates_df["Platform"]=="PS2"]["Platform"].count()
threeDSN = new_dates_df[new_dates_df["Platform"]=="3DS"]["Platform"].count()
PS4N = new_dates_df[new_dates_df["Platform"]=="PS4"]["Platform"].count()
PSN = new_dates_df[new_dates_df["Platform"]=="PS"]["Platform"].count()
XBN = new_dates_df[new_dates_df["Platform"]=="XB"]["Platform"].count()
PCN = new_dates_df[new_dates_df["Platform"]=="PC"]["Platform"].count()
PSPN = new_dates_df[new_dates_df["Platform"]=="PSP"]["Platform"].count()
WiiUN = new_dates_df[new_dates_df["Platform"]=="WiiU"]["Platform"].count()
GCN = new_dates_df[new_dates_df["Platform"]=="GC"]["Platform"].count()
GBAN = new_dates_df[new_dates_df["Platform"]=="GBA"]["Platform"].count()
XOneN = new_dates_df[new_dates_df["Platform"]=="XOne"]["Platform"].count()
PSVN = new_dates_df[new_dates_df["Platform"]=="PSV"]["Platform"].count()
DCN = new_dates_df[new_dates_df["Platform"]=="DC"]["Platform"].count()

platform_dfN = pd.DataFrame(data=[WiiN,DSN,X360N,PS3N,PS2N,threeDSN,PS4N,PSN,XBN,PCN,PSPN,WiiUN,GCN,GBAN,XOneN,PSVN,DCN],columns=["Platform_Counts"])
platform_dfN["Platform"] = ['Wii', 'DS', 'X360', 'PS3', 'PS2', '3DS', 'PS4', 'PS', 'XB', 'PC','PSP', 'WiiU', 'GC', 'GBA', 'XOne', 'PSV', 'DC']
platform_dfN
# Out:
#     Platform_Counts Platform
# 0                 0      Wii
# 1                 0       DS
# 2                 0     X360
# 3                 0      PS3
# 4                 0      PS2
# 5                10      3DS
# 6                92      PS4
# 7                 0       PS
# 8                 0       XB
# 9                37       PC
# 10                0      PSP
# 11                8     WiiU
# 12                0       GC
# 13                0      GBA
# 14               55     XOne
# 15               10      PSV
# 16                0       DC

# %% [markdown]
# ## Which game genre was sold the most in which region?

# %% [markdown]
# ### EU:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(EU_df["Genre"], EU_df["EU_Sales"])
plt.title("All Genre-EU Sales")
plt.xlabel("Genres")
plt.ylabel("EU Sales")

plt.show()

# %%
sns.violinplot(data=EU_df, x = "EU_Sales",y = "Genre");

# %%
sns.jointplot(data=EU_df, x="EU_Sales",y = "Genre");

# %%
sns.factorplot(data=EU_df, x="EU_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# After 2015:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(EU_dfN["Genre"], EU_dfN["EU_Sales"])
plt.title("Nowadays Genre-EU Sales")
plt.xlabel("Genres")
plt.ylabel("EU Sales")

plt.show()

# %%
sns.violinplot(data=EU_dfN, x = "EU_Sales",y = "Genre");

# %%
sns.jointplot(data=EU_dfN, x="EU_Sales",y = "Genre");

# %% [markdown]
# If we compare these graphs we can say that players in Europe used to play action games more. But now, EU players prefer playing shooter games insted of playing action games. Shooter games are the most popular nowadays.

# %%
sns.factorplot(data=EU_dfN, x="EU_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### NA:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(NA_df["Genre"], NA_df["NA_Sales"])
plt.title("All Genre-NA Sales")
plt.xlabel("Genres")
plt.ylabel("NA Sales")

plt.show()

# %%
sns.violinplot(data=NA_df, x = "NA_Sales",y = "Genre");

# %%
sns.jointplot(data=NA_df, x="NA_Sales",y = "Genre");

# %%
sns.factorplot(data=NA_df, x="NA_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# After 2015:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(NA_dfN["Genre"], NA_dfN["NA_Sales"])
plt.title("Nowadays Genre-Na Sales")
plt.xlabel("Genres")
plt.ylabel("NA Sales")

plt.show()

# %%
sns.violinplot(data=NA_dfN, x = "NA_Sales",y = "Genre");

# %%
sns.jointplot(data=NA_dfN, x="NA_Sales",y = "Genre");

# %%
sns.factorplot(data=NA_dfN, x="NA_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# In the past, NA players used to prefer playing action games but nowadays they prefer playing shooter games more.

# %% [markdown]
# ### JP:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(JP_df["Genre"], JP_df["JP_Sales"])
plt.title("All Genre-JP Sales")
plt.xlabel("Genres")
plt.ylabel("JP Sales")

plt.show()

# %%
sns.violinplot(data=JP_df, x = "JP_Sales",y = "Genre");

# %%
sns.jointplot(data=JP_df, x="JP_Sales",y = "Genre");

# %%
sns.factorplot(data=JP_df, x="JP_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# After 2015:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(JP_dfN["Genre"], JP_dfN["JP_Sales"])
plt.title("Nowadays Genre-JP Sales")
plt.xlabel("Genres")
plt.ylabel("JP Sales")

plt.show()

# %%
sns.violinplot(data=JP_dfN, x = "JP_Sales",y = "Genre");

# %%
sns.jointplot(data=JP_dfN, x="JP_Sales",y = "Genre");

# %%
sns.factorplot(data=JP_dfN, x="JP_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Japan players used to play RPG games mostly but nowadays we can not say anything certain. They prefer playing RPG, Shooter and Action games nowadays and they are nearly the same.

# %% [markdown]
# ## Which game genre was sold the most in the world?

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(GL_df["Genre"], GL_df["GL_Sales"])
plt.title("All Genre-Global Sales")
plt.xlabel("Genres")
plt.ylabel("Global Sales")

plt.show()

# %%
sns.violinplot(data=GL_df, x = "GL_Sales",y = "Genre");

# %%
sns.jointplot(data=GL_df, x="GL_Sales",y = "Genre");

# %%
sns.stripplot(data=GL_df, x="GL_Sales",y="Genre");

# %%
sns.factorplot(data=GL_df, x="GL_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# As we can see in these graphs, people used to play action games most. Also Sports and shooter games were popular.

# %% [markdown]
# After 2015:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(GL_dfN["Genre"], GL_dfN["Global_Sales"])
plt.title("Nowadays Genre-Global Sales")
plt.xlabel("Genres")
plt.ylabel("Global Sales")

plt.show()

# %%
sns.violinplot(data=GL_dfN, x = "Global_Sales",y = "Genre");

# %%
sns.jointplot(data=GL_dfN, x="Global_Sales",y = "Genre");

# %%
sns.stripplot(data=GL_dfN, x="Global_Sales",y="Genre");

# %%
sns.factorplot(data=GL_dfN, x="Global_Sales",y="Genre");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# As we can see, after 2015 players all over the world prefer playing shooter games instead of playing other genres. Action games have lost its place.

# %% [markdown]
# ## Which platform is the most popular one?

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(platform_df["Platform"], platform_df["Platform_Counts"])
plt.title("All Platform-Platform Counts")
plt.xlabel("Platforms")
plt.ylabel("Platform Counts")

plt.show()

# %%
sns.violinplot(data=platform_df, x = "Platform",y = "Platform_Counts");

# %%
sns.factorplot(data=platform_df, x="Platform_Counts",y="Platform");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Let's have a look at after 2015 datas:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(platform_dfN["Platform"], platform_dfN["Platform_Counts"])
plt.title("All Platform-Platform Counts")
plt.xlabel("Platforms")
plt.ylabel("Platform Counts")

plt.show()

# %%
sns.violinplot(data=platform_dfN, x = "Platform",y = "Platform_Counts");

# %%
sns.factorplot(data=platform_dfN, x="Platform_Counts",y="Platform");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# As we can see before 2015 there were many kind of platfor games but recently PS4 and then XOne are the most popular ones.

# %% [markdown]
# ## Which game genre is more common in which platform?

# %%
for genre in clean_df["Genre"].unique():
  print(f"{genre}:",clean_df[clean_df["Genre"] == genre].groupby("Platform")["Genre"].count())
# Out:
# Sports: Platform
# 3DS       4
# DC        1
# DS       22
# GBA      19
# GC       66
# PC       28
# PS       16
# PS2     196
# PS3     115
# PS4      39
# PSP      60
# PSV       6
# Wii      73
# WiiU      6
# X360    140
# XB      121
# XOne     31
# Name: Genre, dtype: int64
# Racing: Platform
# 3DS       5
# DC        2
# DS       18
# GBA      21
# GC       31
# PC       43
# PS       17
# PS2     131
# PS3      62
# PS4      15
# PSP      39
# PSV       5
# Wii      30
# WiiU      1
# X360     71
# XB       76
# XOne     14
# Name: Genre, dtype: int64
# Platform: Platform
# 3DS     18
# DC       1
# DS      35
# GBA     48
# GC      44
# PC      10
# PS      16
# PS2     70
# PS3     22
# PS4     11
# PSP     20
# PSV      6
# Wii     36
# WiiU    15
# X360    21
# XB      26
# XOne     4
# Name: Genre, dtype: int64
# Misc: Platform
# 3DS     10
# DS      37
# GBA     12
# GC      16
# PC       3
# PS       4
# PS2     54
# PS3     41
# PS4      7
# PSP     21
# PSV      8
# ...

# %% [markdown]
# All of the times:
#
# Sport: PS2\
# Racing: PS2-PS3\
# Platform: PS2\
# Misc: PS2-PS3\
# Action: PS2-PS3\
# Puzzle: Wii\
# Shooter: PC-PS2-PS3\
# Fighting: PS2-PS3-X360\
# Simulation: PC-PS2\
# RPG: PS2-DS-PS3\
# Adventure: PS2-DS\
# Strategy: PC

# %% [markdown]
# Now let's have a look at nowadays.

# %%
for genre in new_dates_df["Genre"].unique():
  print(f"{genre}:",new_dates_df[new_dates_df["Genre"] == genre].groupby("Platform")["Genre"].count())
# Out:
# Sports: Platform
# PC       4
# PS4     11
# XOne     8
# Name: Genre, dtype: int64
# Shooter: Platform
# PC       8
# PS4     16
# WiiU     1
# XOne    11
# Name: Genre, dtype: int64
# Action: Platform
# 3DS      6
# PC       6
# PS4     30
# PSV      1
# WiiU     4
# XOne    20
# Name: Genre, dtype: int64
# Role-Playing: Platform
# 3DS     1
# PC      4
# PS4     8
# PSV     4
# WiiU    1
# XOne    2
# Name: Genre, dtype: int64
# Fighting: Platform
# PC      1
# PS4     5
# PSV     1
# WiiU    1
# XOne    2
# Name: Genre, dtype: int64
# Racing: Platform
# PC      3
# PS4     7
# XOne    5
# Name: Genre, dtype: int64
# Simulation: Platform
# PC      4
# PS4     1
# XOne    1
# Name: Genre, dtype: int64
# Adventure: Platform
# 3DS     1
# PC      3
# PS4     7
# PSV     3
# XOne    1
# Name: Genre, dtype: int64
# Platform: Platform
# 3DS     1
# PC      1
# PS4     4
# WiiU    1
# XOne    3
# Name: Genre, dtype: int64
# Misc: Platform
# 3DS     1
# PS4     2
# PSV     1
# XOne    1
# ...

# %% [markdown]
# Nowadays:
#
# Sport: PS4-XOne\
# Racing: PS4-XOne-PC\
# Platform: PS4-XOne\
# Misc: All\
# Action: PS4-XOne\
# Puzzle: Wii\
# Shooter: PS4-XOne\
# Fighting: PS4-XOne\
# Simulation: PC\
# RPG: PS4-PSV-PC\
# Adventure: PS4-PC-PSV\
# Strategy: PC

# %% [markdown]
# As we can see these 2 information, PS2 and PS3 used to be the best game platforms but now XOne,Pc and PS4 are the best choises.

# %% [markdown]
# ### Total number of platform games:

# %%
clean_df["Platform"].value_counts()
# Out:
# PS2     1140
# X360     858
# PS3      769
# PC       651
# XB       565
# Wii      479
# DS       464
# PSP      390
# GC       348
# PS4      239
# GBA      237
# XOne     159
# 3DS      155
# PS       150
# PSV      118
# WiiU      89
# DC        14
# Name: Platform, dtype: int64

# %% [markdown]
# ## Which platform has more sale in which region?

# %% [markdown]
# ### NA:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(game_platform, game_NA)
plt.title("Old Platform-NA Sales (Before 2015)")
plt.xlabel("Platform")
plt.ylabel("NA Sales")

plt.show()

# %%
sns.violinplot(x = game_platform,y = game_NA);

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(new_dates_df["Platform"], new_dates_df["NA_Sales"])
plt.title("New Platform-NA Sales")
plt.xlabel("Platform")
plt.ylabel("NA Sales")

plt.show()

# %%
sns.violinplot(x=new_dates_df["Platform"], y=new_dates_df["NA_Sales"]);

# %% [markdown]
# As we can see PS4 and XOne are so close to each other in NA nowadays. But before 2015 Wii was the best platform for players.

# %% [markdown]
# ### EU:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(game_platform, game_EU)
plt.title("Old Platform-EU Sales (Before 2015)")
plt.xlabel("Platform")
plt.ylabel("EU Sales")

plt.show()

# %%
sns.violinplot(x=game_platform, y=game_EU);

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(new_dates_df["Platform"], new_dates_df["EU_Sales"])
plt.title("New Platform-EU Sales")
plt.xlabel("Platform")
plt.ylabel("EU Sales")

plt.show()

# %%
sns.violinplot(new_dates_df["Platform"], new_dates_df["EU_Sales"]);
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# As we can see PS4 is the most common game platform in Europe nowadays. But before 2015 Wii used to be the most common game platform in Europe.

# %% [markdown]
# ### JP:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(game_platform, game_JP)
plt.title("Old Platform-JP Sales (Before 2015)")
plt.xlabel("Platform")
plt.ylabel("JP Sales")

plt.show()

# %%
sns.violinplot(x=game_platform,y= game_JP);

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(new_dates_df["Platform"], new_dates_df["JP_Sales"])
plt.title("New Platform-JP Sales")
plt.xlabel("Platform")
plt.ylabel("JP Sales")

plt.show()

# %%
sns.violinplot(new_dates_df["Platform"], new_dates_df["JP_Sales"]);
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# As we can see in this graph, most Japanese players generally prefer playing with 3DS and then PS4 nowadays. But before 2015, players in Japan used to play with WiiU more.

# %% [markdown]
# ## Which platform game has been sold most in the world?

# %%
WiiS = clean_df[clean_df["Platform"]=="Wii"]["Global_Sales"].sum()
DSS = clean_df[clean_df["Platform"]=="DS"]["Global_Sales"].sum()
X360S = clean_df[clean_df["Platform"]=="X360"]["Global_Sales"].sum()
PS3S = clean_df[clean_df["Platform"]=="PS3"]["Global_Sales"].sum()
PS2S = clean_df[clean_df["Platform"]=="PS2"]["Global_Sales"].sum()
threeDSS = clean_df[clean_df["Platform"]=="3DS"]["Global_Sales"].sum()
PS4S = clean_df[clean_df["Platform"]=="PS4"]["Global_Sales"].sum()
PSS = clean_df[clean_df["Platform"]=="PS"]["Global_Sales"].sum()
XBS = clean_df[clean_df["Platform"]=="XB"]["Global_Sales"].sum()
PCS = clean_df[clean_df["Platform"]=="PC"]["Global_Sales"].sum()
PSPS = clean_df[clean_df["Platform"]=="PSP"]["Global_Sales"].sum()
WiiUS = clean_df[clean_df["Platform"]=="WiiU"]["Global_Sales"].sum()
GCS = clean_df[clean_df["Platform"]=="GC"]["Global_Sales"].sum()
GBAS = clean_df[clean_df["Platform"]=="GBA"]["Global_Sales"].sum()
XOneS = clean_df[clean_df["Platform"]=="XOne"]["Global_Sales"].sum()
PSVS = clean_df[clean_df["Platform"]=="PSV"]["Global_Sales"].sum()
DCS = clean_df[clean_df["Platform"]=="DC"]["Global_Sales"].sum()

platform_Sales_df = pd.DataFrame(data=[WiiS,DSS,X360S,PS3S,PS2S,threeDSS,PS4S,PSS,XBS,PCS,PSPS,WiiUS,GCS,GBAS,XOneS,PSVS,DCS],columns=["Platform_Global_Sales"])
platform_Sales_df["Platform"] = ['Wii', 'DS', 'X360', 'PS3', 'PS2', '3DS', 'PS4', 'PS', 'XB', 'PC','PSP', 'WiiU', 'GC', 'GBA', 'XOne', 'PSV', 'DC']
platform_Sales_df
# Out:
#     Platform_Global_Sales Platform
# 0                  658.98      Wii
# 1                  382.33       DS
# 2                  853.30     X360
# 3                  784.30      PS3
# 4                  945.97      PS2
# 5                  123.23      3DS
# 6                  243.03      PS4
# 7                  206.55       PS
# 8                  212.07       XB
# 9                  187.12       PC
# 10                 187.92      PSP
# 11                  66.08     WiiU
# 12                 159.42       GC
# 13                 131.75      GBA
# 14                 129.57     XOne
# 15                  30.88      PSV
# 16                   4.55       DC

# %%
WiiSN = new_dates_df[new_dates_df["Platform"]=="Wii"]["Global_Sales"].sum()
DSSN = new_dates_df[new_dates_df["Platform"]=="DS"]["Global_Sales"].sum()
X360SN = new_dates_df[new_dates_df["Platform"]=="X360"]["Global_Sales"].sum()
PS3SN = new_dates_df[new_dates_df["Platform"]=="PS3"]["Global_Sales"].sum()
PS2SN = new_dates_df[new_dates_df["Platform"]=="PS2"]["Global_Sales"].sum()
threeDSSN = new_dates_df[new_dates_df["Platform"]=="3DS"]["Global_Sales"].sum()
PS4SN = new_dates_df[new_dates_df["Platform"]=="PS4"]["Global_Sales"].sum()
PSSN = new_dates_df[new_dates_df["Platform"]=="PS"]["Global_Sales"].sum()
XBSN = new_dates_df[new_dates_df["Platform"]=="XB"]["Global_Sales"].sum()
PCSN = new_dates_df[new_dates_df["Platform"]=="PC"]["Global_Sales"].sum()
PSPSN = new_dates_df[new_dates_df["Platform"]=="PSP"]["Global_Sales"].sum()
WiiUSN = new_dates_df[new_dates_df["Platform"]=="WiiU"]["Global_Sales"].sum()
GCSN = new_dates_df[new_dates_df["Platform"]=="GC"]["Global_Sales"].sum()
GBASN = new_dates_df[new_dates_df["Platform"]=="GBA"]["Global_Sales"].sum()
XOneSN = new_dates_df[new_dates_df["Platform"]=="XOne"]["Global_Sales"].sum()
PSVSN = new_dates_df[new_dates_df["Platform"]=="PSV"]["Global_Sales"].sum()
DCSN = new_dates_df[new_dates_df["Platform"]=="DC"]["Global_Sales"].sum()

platform_Sales_dfN = pd.DataFrame(data=[WiiSN,DSSN,X360SN,PS3SN,PS2SN,threeDSSN,PS4SN,PSSN,XBSN,PCSN,PSPSN,WiiUSN,GCSN,GBASN,XOneSN,PSVSN,DCSN],columns=["Platform_Global_Sales"])
platform_Sales_dfN["Platform"] = ['Wii', 'DS', 'X360', 'PS3', 'PS2', '3DS', 'PS4', 'PS', 'XB', 'PC','PSP', 'WiiU', 'GC', 'GBA', 'XOne', 'PSV', 'DC']
platform_Sales_dfN
# Out:
#     Platform_Global_Sales Platform
# 0                    0.00      Wii
# 1                    0.00       DS
# 2                    0.00     X360
# 3                    0.00      PS3
# 4                    0.00      PS2
# 5                    2.18      3DS
# 6                   57.13      PS4
# 7                    0.00       PS
# 8                    0.00       XB
# 9                    4.69       PC
# 10                   0.00      PSP
# 11                   3.25     WiiU
# 12                   0.00       GC
# 13                   0.00      GBA
# 14                  23.36     XOne
# 15                   0.95      PSV
# 16                   0.00       DC

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(platform_Sales_df['Platform'],platform_Sales_df["Platform_Global_Sales"] )
plt.title("Old Platform-Global Sales (Before 2015)")
plt.xlabel("Platform")
plt.ylabel("Global Sales")

plt.show()

# %%
sns.violinplot(data=platform_Sales_df, x = "Platform",y = "Platform_Global_Sales");

# %%
sns.factorplot(data=platform_Sales_df, x="Platform_Global_Sales",y="Platform");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Let's have a look at after 2015:

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.bar(platform_Sales_dfN['Platform'],platform_Sales_dfN["Platform_Global_Sales"] )
plt.title("Nowadays Platform-Global Sales")
plt.xlabel("Platform")
plt.ylabel("Global Sales")

plt.show()

# %%
sns.violinplot(data=platform_Sales_dfN, x = "Platform",y = "Platform_Global_Sales");

# %%
sns.factorplot(data=platform_Sales_dfN, x="Platform_Global_Sales",y="Platform");
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# As we can see before 2015; PS2, PS3 and X360 were the most popular ones and there were not a huge difference between them. But after 2015, PS4 is by far the most popular game platform all over the world.

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ## Global:

# %% [markdown]
# For video games, PS2 and PS3 were the best platforms but now PS4 and XOne are the most-used video game platform.\
# For the graphs, shooter games are very popular recenlty.\
# Shooter games are the most-sold ones. So if you want to make a video game for global sales, a shooter game on PS4 will be the best choice.

# %% [markdown]
# ## NA:

# %% [markdown]
# For video games, PS2 and PS3 were the best platforms but now PS4 and XOne are the most-used video game platform.\
# For the graphs, shooter games are again the most popular ones recenlty in NA.\
# Shooter games are the most-sold ones. So if you want to make a video game for NA sales, a shooter game on PS4 will be the best choice.

# %% [markdown]
# ## EU:

# %% [markdown]
# For video games, PS2 and PS3 were the best platforms but now PS4 and XOne are the most-used video game platform.\
# For the graphs, shooter and sport games are the most popular ones recenlty in EU.\
# Shooter games are the most-sold ones. So if you want to make a video game for EU sales, a shooter (or sports but shooter is the best) game on PS4 will be the best choice again.

# %% [markdown]
# ## JP:

# %% [markdown]
# For video games, PS2 and PS3 were the best platforms but now PS4 and XOne are the most-used video game platform.\
# For the graphs, shooter, RPG and action games are the most popular ones recenlty in JP.\
# RPG games are the most-sold ones. So if you want to make a video game for JP sales, an RPG game on PS4 will be the best choice.
